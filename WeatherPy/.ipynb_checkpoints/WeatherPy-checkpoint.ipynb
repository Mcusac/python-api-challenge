# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# build query and request results
cities_found = []
lat = []
lng = []
temp = []
humidity = []
clouds = []
speed = []
country = []
dt = []


for i, city in enumerate(cities):
    
    query_url = url + 'appid=' + weather_api_key + '&q=' + city
    
    try:
        
        # Get weather data
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        #print(weather_json)

        lat.append(weather_json['coord']['lat'])
        lng.append(weather_json['coord']['lon'])
        temp.append(weather_json['main']['temp'])
        humidity.append(weather_json['main']['humidity'])
        clouds.append(weather_json['clouds']['all'])
        speed.append(weather_json['wind']['speed'])
        country.append(weather_json['sys']['country'])
        dt.append(weather_json['dt'])

        cities_found.append(city)

        # Get the temperature from the response
        #print(f"The weather API responded with: {weather_json}.")
        print(f'Processing record {i + 1} of Set 1 | {city}')
    
    except:
        print("Error: " + city)
# Out:
# Processing record 1 of Set 1 | isangel
# Error: belushya guba
# Processing record 3 of Set 1 | horsham
# Processing record 4 of Set 1 | nishihara
# Processing record 5 of Set 1 | ilulissat
# Processing record 6 of Set 1 | gap
# Processing record 7 of Set 1 | spasskoye
# Processing record 8 of Set 1 | acarau
# Processing record 9 of Set 1 | tautira
# Processing record 10 of Set 1 | bria
# Processing record 11 of Set 1 | butaritari
# Processing record 12 of Set 1 | puerto del rosario
# Error: kamenskoye
# Processing record 14 of Set 1 | punta arenas
# Processing record 15 of Set 1 | new norfolk
# Processing record 16 of Set 1 | luderitz
# Processing record 17 of Set 1 | mandera
# Processing record 18 of Set 1 | port alfred
# Processing record 19 of Set 1 | bethel
# Processing record 20 of Set 1 | torbay
# Processing record 21 of Set 1 | coffs harbour
# Processing record 22 of Set 1 | hithadhoo
# Processing record 23 of Set 1 | fundao
# Processing record 24 of Set 1 | bluff
# Processing record 25 of Set 1 | barrow
# Processing record 26 of Set 1 | jamestown
# Processing record 27 of Set 1 | rikitea
# Processing record 28 of Set 1 | ilhabela
# Processing record 29 of Set 1 | cassilandia
# Processing record 30 of Set 1 | ribeira grande
# Processing record 31 of Set 1 | tasiilaq
# Processing record 32 of Set 1 | puerto ayora
# Processing record 33 of Set 1 | beja
# Processing record 34 of Set 1 | tuktoyaktuk
# Processing record 35 of Set 1 | padang
# Processing record 36 of Set 1 | bredasdorp
# Processing record 37 of Set 1 | chauk
# Processing record 38 of Set 1 | cherskiy
# Error: samatau
# Processing record 40 of Set 1 | busselton
# Processing record 41 of Set 1 | nong phai
# Processing record 42 of Set 1 | salalah
# Processing record 43 of Set 1 | atuona
# Processing record 44 of Set 1 | kathu
# Processing record 45 of Set 1 | eureka
# Processing record 46 of Set 1 | bandarbeyla
# Processing record 47 of Set 1 | georgetown
# Error: barentsburg
# Error: mys shmidta
# Processing record 50 of Set 1 | geraldton
# Processing record 51 of Set 1 | cabo san lucas
# Processing record 52 of Set 1 | saint-joseph
# Error: dolbeau
# Processing record 54 of Set 1 | saldanha
# Processing record 55 of Set 1 | chokurdakh
# Processing record 56 of Set 1 | mataura
# Processing record 57 of Set 1 | hobart
# Processing record 58 of Set 1 | ambilobe
# Processing record 59 of Set 1 | arraial do cabo
# Processing record 60 of Set 1 | ocos
# Processing record 61 of Set 1 | larsnes
# Processing record 62 of Set 1 | pundaguitan
# Processing record 63 of Set 1 | khorol
# Processing record 64 of Set 1 | khatanga
# Processing record 65 of Set 1 | albany
# Processing record 66 of Set 1 | kumylzhenskaya
# Processing record 67 of Set 1 | mandiana
# Processing record 68 of Set 1 | cuenca
# Processing record 69 of Set 1 | thompson
# Processing record 70 of Set 1 | jumla
# Processing record 71 of Set 1 | wanning
# Processing record 72 of Set 1 | keti bandar
# Processing record 73 of Set 1 | almeirim
# Processing record 74 of Set 1 | hasaki
# Processing record 75 of Set 1 | castro
# Processing record 76 of Set 1 | dabhol
# Processing record 77 of Set 1 | kapaa
# Processing record 78 of Set 1 | lasa
# Processing record 79 of Set 1 | clyde river
# Processing record 80 of Set 1 | severo-kurilsk
# Error: kleck
# Processing record 82 of Set 1 | dikson
# Processing record 83 of Set 1 | upernavik
# Processing record 84 of Set 1 | port blair
# Processing record 85 of Set 1 | east london
# Processing record 86 of Set 1 | vaini
# Processing record 87 of Set 1 | manjacaze
# Processing record 88 of Set 1 | zeya
# Processing record 89 of Set 1 | sitka
# Processing record 90 of Set 1 | palmer
# Processing record 91 of Set 1 | fortuna
# Processing record 92 of Set 1 | nikolskoye
# Processing record 93 of Set 1 | devon
# Processing record 94 of Set 1 | tuatapere
# Processing record 95 of Set 1 | douentza
# Processing record 96 of Set 1 | baykit
# Processing record 97 of Set 1 | san cristobal
# Processing record 98 of Set 1 | port elizabeth
# Processing record 99 of Set 1 | hermanus
# Error: nizhneyansk
# Processing record 101 of Set 1 | gimli
# Processing record 102 of Set 1 | carrigaline
# Processing record 103 of Set 1 | innisfail
# Processing record 104 of Set 1 | necochea
# Processing record 105 of Set 1 | tiksi
# Processing record 106 of Set 1 | qaanaaq
# Error: haibowan
# Processing record 108 of Set 1 | lexington
# Processing record 109 of Set 1 | takoradi
# Error: saleaula
# Processing record 111 of Set 1 | divinopolis
# Processing record 112 of Set 1 | yarada
# Processing record 113 of Set 1 | provideniya
# Processing record 114 of Set 1 | kirakira
# Processing record 115 of Set 1 | parrita
# Processing record 116 of Set 1 | phangnga
# Error: tsihombe
# Processing record 118 of Set 1 | hofn
# Processing record 119 of Set 1 | komsomolskiy
# Processing record 120 of Set 1 | nabire
# Processing record 121 of Set 1 | poum
# Processing record 122 of Set 1 | avarua
# Error: umzimvubu
# Processing record 124 of Set 1 | vanavara
# Processing record 125 of Set 1 | micheweni
# Processing record 126 of Set 1 | ushuaia
# Processing record 127 of Set 1 | sesheke
# Processing record 128 of Set 1 | lavrentiya
# Processing record 129 of Set 1 | san quintin
# Processing record 130 of Set 1 | naryan-mar
# Processing record 131 of Set 1 | pierre
# Processing record 132 of Set 1 | hilo
# Processing record 133 of Set 1 | watsa
# Processing record 134 of Set 1 | mezen
# Processing record 135 of Set 1 | laurel
# Processing record 136 of Set 1 | pinawa
# Processing record 137 of Set 1 | pontes e lacerda
# Processing record 138 of Set 1 | leningradskiy
# Processing record 139 of Set 1 | yankton
# Processing record 140 of Set 1 | akalkot
# Processing record 141 of Set 1 | isla vista
# Processing record 142 of Set 1 | nicoya
# Processing record 143 of Set 1 | guaymas
# Processing record 144 of Set 1 | kunashak
# Processing record 145 of Set 1 | korla
# Processing record 146 of Set 1 | mersing
# Processing record 147 of Set 1 | smirnykh
# Processing record 148 of Set 1 | yellowknife
# Error: amderma
# Processing record 150 of Set 1 | carnarvon
# Processing record 151 of Set 1 | pisco
# Processing record 152 of Set 1 | kahului
# Processing record 153 of Set 1 | bignona
# Processing record 154 of Set 1 | gravelbourg
# Processing record 155 of Set 1 | santiago
# Processing record 156 of Set 1 | bilma
# Processing record 157 of Set 1 | fort nelson
# Processing record 158 of Set 1 | umm kaddadah
# Processing record 159 of Set 1 | kodiak
# Processing record 160 of Set 1 | saint-philippe
# Processing record 161 of Set 1 | sambava
# Processing record 162 of Set 1 | trairi
# Error: bolshoye ignatovo
# Error: taolanaro
# Processing record 165 of Set 1 | kurumkan
# Processing record 166 of Set 1 | san patricio
# Processing record 167 of Set 1 | kataysk
# Error: grand river south east
# Processing record 169 of Set 1 | benguela
# Error: illoqqortoormiut
# Processing record 171 of Set 1 | kavaratti
# Processing record 172 of Set 1 | san juan
# Processing record 173 of Set 1 | lagoa
# Processing record 174 of Set 1 | sarana
# Processing record 175 of Set 1 | port lincoln
# Processing record 176 of Set 1 | oranjestad
# Processing record 177 of Set 1 | salisbury
# Processing record 178 of Set 1 | touros
# Processing record 179 of Set 1 | levelland
# Processing record 180 of Set 1 | ormond beach
# Processing record 181 of Set 1 | nanortalik
# Error: attawapiskat
# Processing record 183 of Set 1 | lompoc
# Processing record 184 of Set 1 | valparaiso
# Processing record 185 of Set 1 | cape town
# Processing record 186 of Set 1 | gwadar
# Processing record 187 of Set 1 | janauba
# Processing record 188 of Set 1 | tutoia
# Processing record 189 of Set 1 | sinjar
# Error: buariki
# Error: palabuhanratu
# Processing record 192 of Set 1 | two rivers
# Processing record 193 of Set 1 | luan
# Processing record 194 of Set 1 | jiujiang
# Processing record 195 of Set 1 | salinopolis
# Processing record 196 of Set 1 | campos sales
# Processing record 197 of Set 1 | denpasar
# Processing record 198 of Set 1 | sao filipe
# Processing record 199 of Set 1 | atherton
# Error: louisbourg
# Processing record 201 of Set 1 | chuy
# Processing record 202 of Set 1 | talara
# Processing record 203 of Set 1 | luganville
# Processing record 204 of Set 1 | tura
# Processing record 205 of Set 1 | jati
# Processing record 206 of Set 1 | sehithwa
# Error: satitoa
# Processing record 208 of Set 1 | faanui
# Processing record 209 of Set 1 | tilichiki
# Error: temaraia
# Processing record 211 of Set 1 | karema
# Processing record 212 of Set 1 | sterling
# Processing record 213 of Set 1 | ponta delgada
# Processing record 214 of Set 1 | airai
# Error: bolonchen
# Processing record 216 of Set 1 | mar del plata
# Processing record 217 of Set 1 | williston
# Processing record 218 of Set 1 | mount gambier
# Processing record 219 of Set 1 | bani walid
# Processing record 220 of Set 1 | tranas
# Processing record 221 of Set 1 | biak
# Processing record 222 of Set 1 | bambous virieux
# Processing record 223 of Set 1 | molteno
# Processing record 224 of Set 1 | sao joao da barra
# Processing record 225 of Set 1 | margate
# Processing record 226 of Set 1 | pistsovo
# Processing record 227 of Set 1 | ostrovnoy
# Processing record 228 of Set 1 | mahajanga
# Processing record 229 of Set 1 | kavieng
# Processing record 230 of Set 1 | goure
# Processing record 231 of Set 1 | chapais
# Processing record 232 of Set 1 | skjervoy
# Error: karakendzha
# Processing record 234 of Set 1 | esperance
# Error: hendijan
# Processing record 236 of Set 1 | esna
# Processing record 237 of Set 1 | upington
# Processing record 238 of Set 1 | forecariah
# Processing record 239 of Set 1 | kindu
# Processing record 240 of Set 1 | ixtapa
# Processing record 241 of Set 1 | ornskoldsvik
# Processing record 242 of Set 1 | tiverton
# Processing record 243 of Set 1 | varna
# Processing record 244 of Set 1 | wewak
# Processing record 245 of Set 1 | bima
# Processing record 246 of Set 1 | kysyl-syr
# Processing record 247 of Set 1 | san luis
# Processing record 248 of Set 1 | puerto carreno
# Processing record 249 of Set 1 | varberg
# Processing record 250 of Set 1 | mahebourg
# Processing record 251 of Set 1 | husavik
# Processing record 252 of Set 1 | victoria
# Processing record 253 of Set 1 | stornoway
# Processing record 254 of Set 1 | kalininsk
# Processing record 255 of Set 1 | sabya
# Processing record 256 of Set 1 | iranshahr
# Processing record 257 of Set 1 | belyy yar
# Processing record 258 of Set 1 | takaungu
# Error: doctor pedro p. pena
# Processing record 260 of Set 1 | asau
# Processing record 261 of Set 1 | katsuura
# Processing record 262 of Set 1 | rusape
# Processing record 263 of Set 1 | ancud
# Processing record 264 of Set 1 | carora
# Processing record 265 of Set 1 | kashi
# Processing record 266 of Set 1 | marzuq
# Processing record 267 of Set 1 | leh
# Processing record 268 of Set 1 | guerrero negro
# Processing record 269 of Set 1 | saskylakh
# Error: yuzhno-yeniseyskiy
# Processing record 271 of Set 1 | port hardy
# Processing record 272 of Set 1 | grand gaube
# Processing record 273 of Set 1 | moerai
# Processing record 274 of Set 1 | igarka
# Processing record 275 of Set 1 | mizdah
# Error: marv dasht
# Processing record 277 of Set 1 | namibe
# Processing record 278 of Set 1 | morro bay
# Processing record 279 of Set 1 | kaeo
# Processing record 280 of Set 1 | hatillo
# Processing record 281 of Set 1 | grand forks
# Processing record 282 of Set 1 | klaksvik
# Processing record 283 of Set 1 | gushikawa
# Processing record 284 of Set 1 | pullman
# Processing record 285 of Set 1 | porbandar
# Processing record 286 of Set 1 | tomatlan
# Processing record 287 of Set 1 | port said
# Processing record 288 of Set 1 | cayenne
# Processing record 289 of Set 1 | soyo
# Processing record 290 of Set 1 | matucana
# Processing record 291 of Set 1 | simao
# Processing record 292 of Set 1 | lata
# Processing record 293 of Set 1 | molepolole
# Processing record 294 of Set 1 | bangkalan
# Processing record 295 of Set 1 | robstown
# Processing record 296 of Set 1 | fare
# Processing record 297 of Set 1 | kaitangata
# Processing record 298 of Set 1 | comodoro rivadavia
# Processing record 299 of Set 1 | ca mau
# Processing record 300 of Set 1 | moranbah
# Processing record 301 of Set 1 | vostok
# Processing record 302 of Set 1 | azangaro
# Processing record 303 of Set 1 | naze
# Processing record 304 of Set 1 | mlimba
# Processing record 305 of Set 1 | nouadhibou
# Processing record 306 of Set 1 | rio gallegos
# Processing record 307 of Set 1 | ubinskoye
# Processing record 308 of Set 1 | derbent
# Processing record 309 of Set 1 | keningau
# Processing record 310 of Set 1 | talnakh
# Processing record 311 of Set 1 | ouidah
# Processing record 312 of Set 1 | kalevala
# Processing record 313 of Set 1 | uarini
# Processing record 314 of Set 1 | huicheng
# Processing record 315 of Set 1 | egvekinot
# Processing record 316 of Set 1 | alacranes
# Processing record 317 of Set 1 | bubaque
# Error: vaitupu
# Processing record 319 of Set 1 | tessalit
# Processing record 320 of Set 1 | luau
# Processing record 321 of Set 1 | ulaangom
# Processing record 322 of Set 1 | merritt island
# Processing record 323 of Set 1 | clonakilty
# Processing record 324 of Set 1 | codrington
# Processing record 325 of Set 1 | narsaq
# Processing record 326 of Set 1 | bitung
# Processing record 327 of Set 1 | sao felix do xingu
# Processing record 328 of Set 1 | kemijarvi
# Processing record 329 of Set 1 | dunedin
# Processing record 330 of Set 1 | ponta do sol
# Processing record 331 of Set 1 | dera ismail khan
# Processing record 332 of Set 1 | lebu
# Processing record 333 of Set 1 | macusani
# Processing record 334 of Set 1 | bengkulu
# Processing record 335 of Set 1 | ellensburg
# Processing record 336 of Set 1 | bremerton
# Processing record 337 of Set 1 | kruisfontein
# Processing record 338 of Set 1 | antalaha
# Processing record 339 of Set 1 | tibu
# Processing record 340 of Set 1 | saint-augustin
# Processing record 341 of Set 1 | kalangala
# Error: aflu
# Processing record 343 of Set 1 | hambantota
# Processing record 344 of Set 1 | pangnirtung
# Processing record 345 of Set 1 | hohhot
# Processing record 346 of Set 1 | ranong
# Error: karaul
# Processing record 348 of Set 1 | araouane
# Processing record 349 of Set 1 | san francisco
# Processing record 350 of Set 1 | arlit
# Processing record 351 of Set 1 | boguchany
# Processing record 352 of Set 1 | alice springs
# Processing record 353 of Set 1 | fukue
# Processing record 354 of Set 1 | rawson
# Processing record 355 of Set 1 | cazones
# Processing record 356 of Set 1 | bara
# Processing record 357 of Set 1 | pevek
# Processing record 358 of Set 1 | hanzhong
# Processing record 359 of Set 1 | ekhabi
# Error: marcona
# Processing record 361 of Set 1 | viedma
# Processing record 362 of Set 1 | dingle
# Processing record 363 of Set 1 | hillsborough
# Processing record 364 of Set 1 | catamarca
# Processing record 365 of Set 1 | sampit
# Processing record 366 of Set 1 | moanda
# Processing record 367 of Set 1 | te anau
# Processing record 368 of Set 1 | seminole
# Processing record 369 of Set 1 | santa comba
# Processing record 370 of Set 1 | nagato
# Processing record 371 of Set 1 | ati
# Processing record 372 of Set 1 | sorland
# Error: dinsor
# Processing record 374 of Set 1 | buala
# Processing record 375 of Set 1 | san carlos de bariloche
# Processing record 376 of Set 1 | longyearbyen
# Processing record 377 of Set 1 | omsukchan
# Processing record 378 of Set 1 | butembo
# Processing record 379 of Set 1 | vermilion
# Processing record 380 of Set 1 | jacareacanga
# Processing record 381 of Set 1 | goderich
# Processing record 382 of Set 1 | cururupu
# Processing record 383 of Set 1 | yenagoa
# Processing record 384 of Set 1 | baoqing
# Processing record 385 of Set 1 | kaseda
# Processing record 386 of Set 1 | ambovombe
# Processing record 387 of Set 1 | bairiki
# Processing record 388 of Set 1 | beringovskiy
# Processing record 389 of Set 1 | mantua
# Processing record 390 of Set 1 | colombo
# Processing record 391 of Set 1 | hamilton
# Processing record 392 of Set 1 | agadez
# Processing record 393 of Set 1 | villazon
# Processing record 394 of Set 1 | atoka
# Processing record 395 of Set 1 | beberibe
# Processing record 396 of Set 1 | marawi
# Processing record 397 of Set 1 | yulara
# Processing record 398 of Set 1 | pangai
# Processing record 399 of Set 1 | rocha
# Processing record 400 of Set 1 | barvinkove
# Processing record 401 of Set 1 | sao joaquim
# Processing record 402 of Set 1 | sioux lookout
# Processing record 403 of Set 1 | nara
# Processing record 404 of Set 1 | daru
# Processing record 405 of Set 1 | odessa
# Processing record 406 of Set 1 | cesvaine
# Processing record 407 of Set 1 | haines junction
# Processing record 408 of Set 1 | coihaique
# Processing record 409 of Set 1 | san ignacio
# Processing record 410 of Set 1 | saint-pierre
# Processing record 411 of Set 1 | lorengau
# Error: gilgil
# Processing record 413 of Set 1 | gobabis
# Processing record 414 of Set 1 | salinas
# Processing record 415 of Set 1 | jiangyou
# Processing record 416 of Set 1 | raudeberg
# Processing record 417 of Set 1 | aklavik
# Processing record 418 of Set 1 | oltu
# Processing record 419 of Set 1 | cidreira
# Processing record 420 of Set 1 | fairbanks
# Processing record 421 of Set 1 | college
# Processing record 422 of Set 1 | nemuro
# Processing record 423 of Set 1 | arroyo
# Processing record 424 of Set 1 | bilibino
# Processing record 425 of Set 1 | zhaotong
# Processing record 426 of Set 1 | hobyo
# Processing record 427 of Set 1 | dawlatabad
# Processing record 428 of Set 1 | chantada
# Processing record 429 of Set 1 | bryanka
# Processing record 430 of Set 1 | north platte
# Processing record 431 of Set 1 | yerbogachen
# Processing record 432 of Set 1 | erzin
# Error: sentyabrskiy
# Processing record 434 of Set 1 | tarakan
# Processing record 435 of Set 1 | santander
# Error: tabiauea
# Processing record 437 of Set 1 | goundam
# Processing record 438 of Set 1 | manaus
# Error: chagda
# Processing record 440 of Set 1 | maua
# Processing record 441 of Set 1 | luocheng
# Processing record 442 of Set 1 | namatanai
# Processing record 443 of Set 1 | san lucas toliman
# Error: lolua
# Processing record 445 of Set 1 | chapleau
# Processing record 446 of Set 1 | faya
# Processing record 447 of Set 1 | aksu
# Processing record 448 of Set 1 | ustyuzhna
# Processing record 449 of Set 1 | oda
# Processing record 450 of Set 1 | toyokawa
# Processing record 451 of Set 1 | kiruna
# Processing record 452 of Set 1 | zurrieq
# Processing record 453 of Set 1 | bosaso
# Processing record 454 of Set 1 | campoverde
# Processing record 455 of Set 1 | waddan
# Processing record 456 of Set 1 | snyder
# Processing record 457 of Set 1 | galesong
# Processing record 458 of Set 1 | lloret de mar
# Processing record 459 of Set 1 | kazanskoye
# Processing record 460 of Set 1 | pangody
# Processing record 461 of Set 1 | marabba
# Processing record 462 of Set 1 | bokoro
# Processing record 463 of Set 1 | zyryanka
# Processing record 464 of Set 1 | ballina
# Processing record 465 of Set 1 | broome
# Processing record 466 of Set 1 | shimoda
# Processing record 467 of Set 1 | hammerfest
# Processing record 468 of Set 1 | saint george
# Processing record 469 of Set 1 | tabou
# Processing record 470 of Set 1 | shaowu
# Error: ardistan
# Processing record 472 of Set 1 | buchanan
# Processing record 473 of Set 1 | vicente guerrero
# Processing record 474 of Set 1 | machali
# Processing record 475 of Set 1 | honningsvag
# Processing record 476 of Set 1 | anadyr
# Processing record 477 of Set 1 | arrecife
# Processing record 478 of Set 1 | abbeville
# Processing record 479 of Set 1 | taltal
# Processing record 480 of Set 1 | cooma
# Processing record 481 of Set 1 | lat yao
# Processing record 482 of Set 1 | nova vicosa
# Processing record 483 of Set 1 | garissa
# Processing record 484 of Set 1 | bugiri
# Processing record 485 of Set 1 | hailar
# Processing record 486 of Set 1 | port macquarie
# Processing record 487 of Set 1 | brae
# Processing record 488 of Set 1 | champerico
# Error: dianopolis
# Processing record 490 of Set 1 | ludwigsfelde
# Processing record 491 of Set 1 | kabwe
# Processing record 492 of Set 1 | rokupr
# Processing record 493 of Set 1 | sao jose da coroa grande
# Processing record 494 of Set 1 | samarai
# Processing record 495 of Set 1 | yangjiang
# Processing record 496 of Set 1 | glenwood springs
# Processing record 497 of Set 1 | manacapuru
# Error: yanan
# Processing record 499 of Set 1 | haicheng
# Processing record 500 of Set 1 | makakilo city
# Processing record 501 of Set 1 | kulhudhuffushi
# Processing record 502 of Set 1 | prieska
# Processing record 503 of Set 1 | lakatoro
# Processing record 504 of Set 1 | falun
# Processing record 505 of Set 1 | prince rupert
# Processing record 506 of Set 1 | warrington
# Processing record 507 of Set 1 | ratnagiri
# Processing record 508 of Set 1 | pozhva
# Processing record 509 of Set 1 | villacarrillo
# Processing record 510 of Set 1 | mataram
# Processing record 511 of Set 1 | grand-bourg
# Processing record 512 of Set 1 | anloga
# Processing record 513 of Set 1 | uberlandia
# Processing record 514 of Set 1 | marrakesh
# Processing record 515 of Set 1 | bonthe
# Error: sigerfjord
# Processing record 517 of Set 1 | amberley
# Error: taburi
# Processing record 519 of Set 1 | benoy
# Processing record 520 of Set 1 | takhtamygda
# Processing record 521 of Set 1 | lingyuan
# Processing record 522 of Set 1 | iqaluit
# Processing record 523 of Set 1 | nelson bay
# Processing record 524 of Set 1 | saint anthony
# Processing record 525 of Set 1 | batsfjord
# Processing record 526 of Set 1 | hokitika
# Processing record 527 of Set 1 | felanitx
# Processing record 528 of Set 1 | malinovoye ozero
# Processing record 529 of Set 1 | okha
# Processing record 530 of Set 1 | lakhnadon
# Processing record 531 of Set 1 | honiara
# Processing record 532 of Set 1 | kismayo
# Processing record 533 of Set 1 | taoudenni
# Error: bolungarvik
# Error: rungata
# Error: barawe
# Processing record 537 of Set 1 | abu dhabi
# Processing record 538 of Set 1 | debre tabor
# Processing record 539 of Set 1 | camopi
# Processing record 540 of Set 1 | yumen
# Processing record 541 of Set 1 | sembe
# Processing record 542 of Set 1 | acajutla
# Processing record 543 of Set 1 | noumea
# Processing record 544 of Set 1 | acapulco
# Processing record 545 of Set 1 | jalu
# Processing record 546 of Set 1 | antofagasta
# Processing record 547 of Set 1 | ashington
# Processing record 548 of Set 1 | chara
# Processing record 549 of Set 1 | marang
# Processing record 550 of Set 1 | chumikan
# Processing record 551 of Set 1 | tazovskiy
# Processing record 552 of Set 1 | bandipur
# Error: samusu
# Processing record 554 of Set 1 | kaduna
# Processing record 555 of Set 1 | lana
# Processing record 556 of Set 1 | hay river
# Processing record 557 of Set 1 | thinadhoo
# Processing record 558 of Set 1 | olinda
# Processing record 559 of Set 1 | deputatskiy
# Processing record 560 of Set 1 | sayyan
# Processing record 561 of Set 1 | spodnja idrija
# Processing record 562 of Set 1 | hualmay
# Processing record 563 of Set 1 | tandayag
# Processing record 564 of Set 1 | medea
# Processing record 565 of Set 1 | vangaindrano
# Processing record 566 of Set 1 | aginskoye
# Error: ondorhaan
# Processing record 568 of Set 1 | amahai
# Processing record 569 of Set 1 | richards bay
# Processing record 570 of Set 1 | turek
# Processing record 571 of Set 1 | ribeira brava
# Processing record 572 of Set 1 | vallenar
# Processing record 573 of Set 1 | roma
# Processing record 574 of Set 1 | roros
# Processing record 575 of Set 1 | salto
# Processing record 576 of Set 1 | evensk
# Processing record 577 of Set 1 | pitimbu
# Processing record 578 of Set 1 | fayaoue
# Processing record 579 of Set 1 | lyubech
# Processing record 580 of Set 1 | rancho veloz
# Processing record 581 of Set 1 | marsa matruh
# Processing record 582 of Set 1 | teeli
# Processing record 583 of Set 1 | gibgos
# Processing record 584 of Set 1 | pokhara
# Processing record 585 of Set 1 | corrales
# Processing record 586 of Set 1 | cockburn town
# Processing record 587 of Set 1 | morehead
# Processing record 588 of Set 1 | dubbo
# Processing record 589 of Set 1 | janakpur
# Processing record 590 of Set 1 | mormugao
# Processing record 591 of Set 1 | soloneshnoye
# Processing record 592 of Set 1 | kropotkin
# Processing record 593 of Set 1 | derzhavinsk
# Error: mme
# Error: warqla
# Processing record 596 of Set 1 | stanceni
# Processing record 597 of Set 1 | sonoita
# Processing record 598 of Set 1 | vredendal
# Processing record 599 of Set 1 | grindavik
# Processing record 600 of Set 1 | los llanos de aridane
# Processing record 601 of Set 1 | takapau
# Processing record 602 of Set 1 | vodnyy

# %%
weather_dict = {
    "City": cities_found,
    "Latitude": lat,
    'Longitude': lng,
    "Max Temperature": temp,
    'Humidity': humidity,
    'Cloudiness': clouds,
    'Wind Speed': speed,
    'Country': country,
    'Date': dt
    
}
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                  isangel -19.5500  169.2667    297.33        86         100
# 1                  horsham  51.0640   -0.3272    281.79        79           0
# 2                nishihara  26.1842  127.7558    299.99        91          75
# 3                ilulissat  69.2167  -51.1000    270.16        93          40
# 4                      gap  44.6667    6.0000    277.50        70           2
# ..                     ...      ...       ...       ...       ...         ...
# 546              vredendal -31.6683   18.5012    287.68        88          27
# 547              grindavik  63.8424  -22.4338    281.41       100          75
# 548  los llanos de aridane  28.6585  -17.9182    288.77        91          75
# 549                takapau -40.0333  176.3500    286.89        62          74
# 550                 vodnyy  63.5046   53.4095    268.08        83           8
#
#      Wind Speed Country        Date
# 0          7.88      VU  1651188167
# 1          3.09      GB  1651188277
# 2          7.72      JP  1651188193
# 3          2.06      GL  1651188277
# 4          1.23      FR  1651188278
# ..          ...     ...         ...
# 546        5.48      ZA  1651188432
# 547        5.14      IS  1651188464
# 548        4.63      ES  1651188464
# 549        1.93      NZ  1651188465
# 550        2.43      RU  1651188465
#
# [551 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data.to_csv(
    path_or_buf = "output_data/cities.csv"
)
weather_data.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    isangel -19.5500  169.2667    297.33        86         100        7.88
# 1    horsham  51.0640   -0.3272    281.79        79           0        3.09
# 2  nishihara  26.1842  127.7558    299.99        91          75        7.72
# 3  ilulissat  69.2167  -51.1000    270.16        93          40        2.06
# 4        gap  44.6667    6.0000    277.50        70           2        1.23
#
#   Country        Date
# 0      VU  1651188167
# 1      GB  1651188277
# 2      JP  1651188193
# 3      GL  1651188277
# 4      FR  1651188278

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humid_df = weather_data.loc(weather_data['Humidity'] > 100)

humid_df
print(humid_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13832/3860465121.py in <module>
#       1 #  Get the indices of cities that have humidity over 100%.
# ----> 2 humid_df = weather_data.loc(weather_data['Humidity'] > 100)
#       3
#       4 humid_df
#       5 print(humid_df)
#
# E:\ProgramFiles\anaconda\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     635
#     636         if axis is not None:
# --> 637             axis = self.obj._get_axis_number(axis)
#     638         new_self.axis = axis
#     639         return new_self
#
# E:\ProgramFiles\anaconda\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     544     def _get_axis_number(cls, axis: Axis) -> int:
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#     548             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'Series'

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = df[df.Humidity > 100]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.title('City Latitude vs. Max Temperature (F) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

x1 = lat
y1 = temp

plt.scatter(x1, y1)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.title('City Latitude vs. Humidity (%) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

x2 = lat
y2 = humidity

plt.scatter(x2, y2)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.title('City Latitude vs. Cloudiness (%) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

x3 = lat
y3 = clouds

plt.scatter(x3, y3)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.title('City Latitude vs. Wind Speed (mph) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

x4 = lat
y4 = speed

plt.scatter(x4, y4)

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.title('Northern Hemisphere - City Latitude vs. Max Temperature (F) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

x5 = lat
y5 = temp

plt.scatter(x5, y5)

(slope, intercept, r, p, se) = st.linregress(x5, y5)
regress_values = x5 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The value of r-squared is: {r**2}")
plt.plot(x5,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")

correlation = st.pearsonr(x5, y5)
print(f'The correlation between both factors is {round(correlation[0],2)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13832/3104540828.py in <module>
#       8 plt.scatter(x5, y5)
#       9
# ---> 10 (slope, intercept, r, p, se) = st.linregress(x5, y5)
#      11 regress_values = x5 * slope + intercept
#      12 line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# NameError: name 'st' is not defined

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.title('Southern Hemisphere - City Latitude vs. Max Temperature (F) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

x6 = lat
y6 = temp

plt.scatter(x6, y6)

correlation = st.pearsonr(x6, y6)
print(f'The correlation between both factors is {round(correlation[0],2)}')

(slope, intercept, r, p, se) = st.linregress(x6, y6)
regress_values = x6 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The value of r-squared is: {r**2}")
plt.plot(x6,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13832/261499862.py in <module>
#       8 plt.scatter(x6, y6)
#       9
# ---> 10 correlation = st.pearsonr(x6, y6)
#      11 print(f'The correlation between both factors is {round(correlation[0],2)}')
#      12
#
# NameError: name 'st' is not defined

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.title('Northern Hemisphere - City Latitude vs. Humidity (%) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

x7 = lat
y7 = humidity

plt.scatter(x7, y7)

correlation = st.pearsonr(x7, y7)
print(f'The correlation between both factors is {round(correlation[0],2)}')

(slope, intercept, r, p, se) = st.linregress(x7, y7)
regress_values = x7 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The value of r-squared is: {r**2}")
plt.plot(x7,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13832/1910750675.py in <module>
#       8 plt.scatter(x7, y7)
#       9
# ---> 10 correlation = st.pearsonr(x7, y7)
#      11 print(f'The correlation between both factors is {round(correlation[0],2)}')
#      12
#
# NameError: name 'st' is not defined

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.title('Southern Hemisphere - City Latitude vs. Humidity (%) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

x8 = lat
y8 = humidity

plt.scatter(x8, y8)

correlation = st.pearsonr(x8, y8)
print(f'The correlation between both factors is {round(correlation[0],2)}')

(slope, intercept, r, p, se) = st.linregress(x8, y8)
regress_values = x8 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The value of r-squared is: {r**2}")
plt.plot(x8,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13832/2746478888.py in <module>
#       8 plt.scatter(x8, y8)
#       9
# ---> 10 correlation = st.pearsonr(x8, y8)
#      11 print(f'The correlation between both factors is {round(correlation[0],2)}')
#      12
#
# NameError: name 'st' is not defined

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.title('Northern Hemisphere - City Latitude vs. Cloudiness (%) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

x9 = lat
y9 = clouds

plt.scatter(x9, y9)

correlation = st.pearsonr(x9, y9)
print(f'The correlation between both factors is {round(correlation[0],2)}')

(slope, intercept, r, p, se) = st.linregress(x9, y9)
regress_values = x9 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The value of r-squared is: {r**2}")
plt.plot(x9,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13832/3841179882.py in <module>
#       8 plt.scatter(x9, y9)
#       9
# ---> 10 correlation = st.pearsonr(x9, y9)
#      11 print(f'The correlation between both factors is {round(correlation[0],2)}')
#      12
#
# NameError: name 'st' is not defined

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.title('Southern Hemisphere - City Latitude vs. Cloudiness (%) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

x10 = lat
y10 = clouds

plt.scatter(x10, y10)

correlation = st.pearsonr(x10, y10)
print(f'The correlation between both factors is {round(correlation[0],2)}')

(slope, intercept, r, p, se) = st.linregress(x10, y10)
regress_values = x10 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The value of r-squared is: {r**2}")
plt.plot(x10,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13832/3085205554.py in <module>
#       8 plt.scatter(x10, y10)
#       9
# ---> 10 correlation = st.pearsonr(x10, y10)
#      11 print(f'The correlation between both factors is {round(correlation[0],2)}')
#      12
#
# NameError: name 'st' is not defined

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.title('Northern Hemisphere - City Latitude vs. Wind Speed (mph) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

x11 = lat
y11 = speed

plt.scatter(x11, y11)

correlation = st.pearsonr(x11, y11)
print(f'The correlation between both factors is {round(correlation[0],2)}')

(slope, intercept, r, p, se) = st.linregress(x11, y11)
regress_values = x11 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The value of r-squared is: {r**2}")
plt.plot(x11,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13832/1987665800.py in <module>
#       8 plt.scatter(x11, y11)
#       9
# ---> 10 correlation = st.pearsonr(x11, y11)
#      11 print(f'The correlation between both factors is {round(correlation[0],2)}')
#      12
#
# NameError: name 'st' is not defined

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.title('Southern Hemisphere - City Latitude vs. Wind Speed (mph) (04/25/22)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

x12 = lat
y12 = speed

plt.scatter(x12, y12)

correlation = st.pearsonr(x12, y12)
print(f'The correlation between both factors is {round(correlation[0],2)}')

(slope, intercept, r, p, se) = st.linregress(x12, y12)
regress_values = x12 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The value of r-squared is: {r**2}")
plt.plot(x12,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13832/2775844387.py in <module>
#       8 plt.scatter(x12, y12)
#       9
# ---> 10 correlation = st.pearsonr(x12, y12)
#      11 print(f'The correlation between both factors is {round(correlation[0],2)}')
#      12
#
# NameError: name 'st' is not defined
